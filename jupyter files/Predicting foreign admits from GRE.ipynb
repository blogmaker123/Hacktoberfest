# %% [markdown]
# Every year many students give the GRE exam to get admission in foreign Universities. <br>
# The dataset contains  GRE  Scores(out  of  340), TOEFL  Scores(out  of  120), University  Rating  (out  of  5),<br>
# SOP(out of 5),LOR Strength(out of 5),Undergraduate GPA(out of 10), Research Experience(0=no,1=yes),<br>
# Admitted (0=no, 1=yes). Admitted is the target variable.<br>
# <br>
# The counselor of the firm is supposed check whether the student will get an admission or not based on his/her GRE score and Academic Score. <br>
# So to help the counselor to take appropriate decisions build a machine learning model classifier <br>
# using Decision tree to predict whether a student will get admission or not.<br>
#
# A) Apply Data pre-processing (LabelEncoding,DataTransformation....)techniques if necessary.<br>
# B) Perform data-preparation (Train-Test Split)<br>
# C) Apply Machine Learning Algorithm<br>
# D) Evaluate Model.<br>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Admission_Predict.csv')
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1              0.92
# 1             2        324          107  ...  8.87         1              0.76
# 2             3        316          104  ...  8.00         1              0.72
# 3             4        322          110  ...  8.67         1              0.80
# 4             5        314          103  ...  8.21         0              0.65
# ..          ...        ...          ...  ...   ...       ...               ...
# 395         396        324          110  ...  9.04         1              0.82
# 396         397        325          107  ...  9.11         1              0.84
# 397         398        330          116  ...  9.45         1              0.91
# 398         399        312          103  ...  8.78         0              0.67
# 399         400        333          117  ...  9.66         1              0.95
#
# [400 rows x 9 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1              0.92
# 1             2        324          107  ...  8.87         1              0.76
# 2             3        316          104  ...  8.00         1              0.72
# 3             4        322          110  ...  8.67         1              0.80
# 4             5        314          103  ...  8.21         0              0.65
# ..          ...        ...          ...  ...   ...       ...               ...
# 395         396        324          110  ...  9.04         1              0.82
# 396         397        325          107  ...  9.11         1              0.84
# 397         398        330          116  ...  9.45         1              0.91
# 398         399        312          103  ...  8.78         0              0.67
# ...

# %%
df.shape
# Out:
# (400, 9)

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
df.dtypes
# Out:
# Serial No.             int64
# GRE Score              int64
# TOEFL Score            int64
# University Rating      int64
# SOP                  float64
# LOR                  float64
# CGPA                 float64
# Research               int64
# Chance of Admit      float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %%
s1= df[df['Chance of Admit ']>0.80]
s1['Chance of Admit '].count()
# Out:
# 117

# %%
# if chance of admit >= 80% then :: chance of admit = 1
# if chance of admit < 80%  then :: chance of admit = 0
df.loc[df['Chance of Admit '] >=0.80, 'Chance of Admit ']=1
df.loc[df['Chance of Admit '] <0.80, 'Chance of Admit ']=0

# displaying the updated column of CHANCE OF ADMIT
df['Chance of Admit ']
# Out:
# 0      1.0
# 1      0.0
# 2      0.0
# 3      1.0
# 4      0.0
#       ...
# 395    1.0
# 396    1.0
# 397    1.0
# 398    0.0
# 399    1.0
# Name: Chance of Admit , Length: 400, dtype: float64

# %%
df
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 0             1        337          118  ...  9.65         1               1.0
# 1             2        324          107  ...  8.87         1               0.0
# 2             3        316          104  ...  8.00         1               0.0
# 3             4        322          110  ...  8.67         1               1.0
# 4             5        314          103  ...  8.21         0               0.0
# ..          ...        ...          ...  ...   ...       ...               ...
# 395         396        324          110  ...  9.04         1               1.0
# 396         397        325          107  ...  9.11         1               1.0
# 397         398        330          116  ...  9.45         1               1.0
# 398         399        312          103  ...  8.78         0               0.0
# 399         400        333          117  ...  9.66         1               1.0
#
# [400 rows x 9 columns]

# %%
#highest GRE Score
print('Max GRE Score : ',df['GRE Score'].max())

#lowest GRE Score
print('Min GRE Score : ',df['GRE Score'].min())
# Out:
# Max GRE Score :  340
# Min GRE Score :  290

# %%
df.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Chance of Admit '],
#       dtype='object')

# %%
# Importing required libraries
# Loading the dataset
# displaying the dataset
#data type of each column
# displaying columns
# displaying shape
# updating chance of admission column
# changing from PERCENTAGE to (0 OR 1)
# if chance >= 80% CHANCE = 1
# if chance < 80%  CHANCE = 0
# displaying the updated column of CHANCE OF ADMIT
# Minimum and maximum GRE Scores
# dividing dataset in training (75%) and testing (25%).

# %%
from sklearn.model_selection import train_test_split

# dividing dataset in training (75%) and testing (25%).
train, test = train_test_split(df,test_size=0.25,train_size=0.75)

# %%
train
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 116         117        299          102  ...  8.62         0               0.0
# 370         371        310          103  ...  8.24         0               0.0
# 316         317        298          101  ...  7.86         0               0.0
# 169         170        311           99  ...  7.98         0               0.0
# 30           31        300           97  ...  8.10         1               0.0
# ..          ...        ...          ...  ...   ...       ...               ...
# 168         169        293           97  ...  7.80         1               0.0
# 397         398        330          116  ...  9.45         1               1.0
# 321         322        323          104  ...  8.44         1               0.0
# 352         353        303          100  ...  8.06         1               0.0
# 62           63        304          105  ...  8.20         1               0.0
#
# [300 rows x 9 columns]

# %%
test
# Out:
#      Serial No.  GRE Score  TOEFL Score  ...  CGPA  Research  Chance of Admit
# 230         231        313          104  ...  8.65         0               0.0
# 314         315        305          105  ...  8.13         0               0.0
# 135         136        314          109  ...  8.77         1               1.0
# 329         330        297           96  ...  7.89         0               0.0
# 120         121        335          117  ...  9.56         1               1.0
# ..          ...        ...          ...  ...   ...       ...               ...
# 208         209        305          106  ...  8.16         0               0.0
# 66           67        327          114  ...  9.02         0               0.0
# 63           64        315          107  ...  8.50         1               0.0
# 64           65        325          111  ...  8.70         0               0.0
# 147         148        326          114  ...  9.11         1               1.0
#
# [100 rows x 9 columns]

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
#Defining features and target variable
x = df.drop( ['Chance of Admit ','Serial No.'],axis=1) #set of required features, in this case all
y = df['Chance of Admit '] #target variable we want to predict 

#Splitting the data into train and test set 
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)
print(X_train)
print('\n',X_test)
print('\n',y_train)
print('\n',y_test)
# Out:
#      GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  Research
# 247        311          104                  2  2.5   3.5  8.48         0
# 110        305          108                  5  3.0   3.0  8.48         0
# 16         317          107                  3  4.0   3.0  8.70         0
# 66         327          114                  3  3.0   3.0  9.02         0
# 153        324          105                  3  3.0   4.0  8.75         0
# ..         ...          ...                ...  ...   ...   ...       ...
# 71         336          112                  5  5.0   5.0  9.76         1
# 106        329          111                  4  4.5   4.5  9.18         1
# 270        306          105                  2  2.5   3.0  8.22         1
# 348        302           99                  1  2.0   2.0  7.25         0
# 102        314          106                  2  4.0   3.5  8.25         0
#
# [300 rows x 7 columns]
#
# ...

# %%
#Predicting using Logistic Regression for Binary classification 
from sklearn.linear_model import LogisticRegression

# %%
#LR = LogisticRegression()
#LR.fit(X_train,y_train) #fitting the model 
#y_pred = LR.predict(X_test) #prediction

# %%
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
# Create Decision Tree classifer object
model = DecisionTreeClassifier()

# Train Decision Tree Classifer
model.fit(X_train,y_train)

#Predict the response for test dataset
y_pred=model.predict(X_test)

# %%
# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix : \n")
cnf_matrix
# Out:
# Confusion Matrix :
# array([[64,  2],
#        [ 6, 28]])

# %%
#extracting true_positives, false_positives, true_negatives, false_negatives
tn, fp, fn, tp = confusion_matrix(y_test, y_pred).ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# True Negatives:  64
# False Positives:  2
# False Negatives:  6
# True Positives:  28

# %%
#Accuracy
Accuracy = (tn+tp)*100/(tp+tn+fp+fn) 
print("Accuracy {:0.2f}%:".format(Accuracy))
# Out:
# Accuracy 92.00%:

# %%
#Precision 
Precision = tp/(tp+fp) 
print("Precision {:0.2f}".format(Precision))
# Out:
# Precision 0.93

# %%
#Recall 
Recall = tp/(tp+fn) 
print("Recall {:0.2f}".format(Recall))
# Out:
# Recall 0.82

# %%
#F1 Score
f1 = (2*Precision*Recall)/(Precision + Recall)
print("F1 Score {:0.2f}".format(f1))
# Out:
# F1 Score 0.87

# %%
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.92

# %%
#classification report
matrix = classification_report(y_test,y_pred)
print("Classification report :\n",matrix)
# Out:
# Classification report :
#                precision    recall  f1-score   support
#
#          0.0       0.91      0.97      0.94        66
#          1.0       0.93      0.82      0.87        34
#
#     accuracy                           0.92       100
#    macro avg       0.92      0.90      0.91       100
# weighted avg       0.92      0.92      0.92       100

# %%
x.columns
# Out:
# Index(['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA',
#        'Research'],
#       dtype='object')

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names = ['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research'],class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('Admission_Predict.png')
Image(graph.create_png())
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)

# %%
import matplotlib.pyplot as plt
from sklearn import tree
fig = plt.figure(figsize=(40,30))
desciion_tree = tree.plot_tree(model, 
                   feature_names=['GRE Score', 'TOEFL Score', 'University Rating', 'SOP', 'LOR ', 'CGPA', 'Research'], 
                   class_names=['0','1'],
                   filled=True)
